# %%
# import pandas
import pandas as pd

# %%
# upload data set and rename credit
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
# quick view of data frame
credit.head()
# Out:
#    ID  Credit Amount  Gender  Education  Marital Status  Age  Repay_Sept  \
# 0   1          20000       2          2               1   24           2
# 1   2         120000       2          2               2   26          -1
# 2   3          90000       2          2               2   34           0
# 3   4          50000       2          2               1   37           0
# 4   5          50000       1          2               1   57          -1
#
#    Repay_Aug  Repay_July  Repay_June   ...     Bill_June  Bill_May  \
# 0          2          -1          -1   ...             0         0
# 1          2           0           0   ...          3272      3455
# 2          0           0           0   ...         14331     14948
# 3          0           0           0   ...         28314     28959
# 4          0          -1           0   ...         20940     19146
#
#    Bill_April  PrevAmt_Sept  PrevAmt_Aug  PrevAmt_July  PrevAmt_June  \
# ...

# %%
# using describe function for high level understanding of data
credit.describe()
# Out:
#                  ID   Credit Amount        Gender     Education  \
# count  30000.000000    30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133
# std     8660.398374   129747.661567      0.489129      0.790349
# min        1.000000    10000.000000      1.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000
#
#        Marital Status           Age    Repay_Sept     Repay_Aug    Repay_July  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean         1.551867     35.485500     -0.016700     -0.133767     -0.166200
# std          0.521970      9.217904      1.123802      1.197186      1.196868
# ...

# %%
# checking data types
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                30000 non-null int64
# Credit Amount     30000 non-null int64
# Gender            30000 non-null int64
# Education         30000 non-null int64
# Marital Status    30000 non-null int64
# Age               30000 non-null int64
# Repay_Sept        30000 non-null int64
# Repay_Aug         30000 non-null int64
# Repay_July        30000 non-null int64
# Repay_June        30000 non-null int64
# Repay_May         30000 non-null int64
# Repay_April       30000 non-null int64
# Bill_Sept         30000 non-null int64
# Bill_Aug          30000 non-null int64
# Bill_July         30000 non-null int64
# Bill_June         30000 non-null int64
# Bill_May          30000 non-null int64
# Bill_April        30000 non-null int64
# PrevAmt_Sept      30000 non-null int64
# PrevAmt_Aug       30000 non-null int64
# PrevAmt_July      30000 non-null int64
# ...

# %%
# changing data types for gender, education, marital status and default
credit['Gender'] = credit['Gender'].astype('str')
credit['Eduction'] = credit['Education'].astype('str')
credit['Marital Status'] = credit['Marital Status'].astype('str')
credit['Default'] = credit['Default'].astype('str')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 26 columns):
# ID                30000 non-null int64
# Credit Amount     30000 non-null int64
# Gender            30000 non-null object
# Education         30000 non-null int64
# Marital Status    30000 non-null object
# Age               30000 non-null int64
# Repay_Sept        30000 non-null int64
# Repay_Aug         30000 non-null int64
# Repay_July        30000 non-null int64
# Repay_June        30000 non-null int64
# Repay_May         30000 non-null int64
# Repay_April       30000 non-null int64
# Bill_Sept         30000 non-null int64
# Bill_Aug          30000 non-null int64
# Bill_July         30000 non-null int64
# Bill_June         30000 non-null int64
# Bill_May          30000 non-null int64
# Bill_April        30000 non-null int64
# PrevAmt_Sept      30000 non-null int64
# PrevAmt_Aug       30000 non-null int64
# PrevAmt_July      30000 non-null int64
# ...

# %%
# spelling Education correctly
credit['Education'] = credit['Education'].astype('str')

# %%
# removing Eduction column
del credit['Eduction']

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                30000 non-null int64
# Credit Amount     30000 non-null int64
# Gender            30000 non-null object
# Education         30000 non-null object
# Marital Status    30000 non-null object
# Age               30000 non-null int64
# Repay_Sept        30000 non-null int64
# Repay_Aug         30000 non-null int64
# Repay_July        30000 non-null int64
# Repay_June        30000 non-null int64
# Repay_May         30000 non-null int64
# Repay_April       30000 non-null int64
# Bill_Sept         30000 non-null int64
# Bill_Aug          30000 non-null int64
# Bill_July         30000 non-null int64
# Bill_June         30000 non-null int64
# Bill_May          30000 non-null int64
# Bill_April        30000 non-null int64
# PrevAmt_Sept      30000 non-null int64
# PrevAmt_Aug       30000 non-null int64
# PrevAmt_July      30000 non-null int64
# ...

# %%
# import matplotlib for visualization
import pandas as pd
import matplotlib.pyplot as plt

# %%
# understanding column names
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'Credit Amount', 'Gender', 'Education', 'Marital Status', 'Age',
#        'Repay_Sept', 'Repay_Aug', 'Repay_July', 'Repay_June', 'Repay_May',
#        'Repay_April', 'Bill_Sept', 'Bill_Aug', 'Bill_July', 'Bill_June',
#        'Bill_May', 'Bill_April', 'PrevAmt_Sept', 'PrevAmt_Aug', 'PrevAmt_July',
#        'PrevAmt_June', 'PrevAmt_May', 'PrevAmt_April', 'Default'],
#       dtype='object')

# %%
plt.hist(credit['Credit Amount'])
plt.show()

# %%
plt.hist(credit['Credit Amount'], bins = 4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
# looking at age, 4 bins
plt.hist(credit['Age'], bins = 4)
# Out:
# (array([16809., 10511.,  2570.,   110.]),
#  array([21. , 35.5, 50. , 64.5, 79. ]),
#  <a list of 4 Patch objects>)

# %%
plt.plot(credit['Credit Amount'])
plt.show()

# %%
x = credit['Repay_Sept']
y = credit['Repay_Aug']
plt.scatter(x,y)
plt.show()

# %%
x = credit['Age']
y = credit['Default']

# %%
plt.scatter(x,y)
plt.show()

# %%
# looking at box plot
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'Credit Amount', 'Gender', 'Education', 'Marital Status', 'Age',
#        'Repay_Sept', 'Repay_Aug', 'Repay_July', 'Repay_June', 'Repay_May',
#        'Repay_April', 'Bill_Sept', 'Bill_Aug', 'Bill_July', 'Bill_June',
#        'Bill_May', 'Bill_April', 'PrevAmt_Sept', 'PrevAmt_Aug', 'PrevAmt_July',
#        'PrevAmt_June', 'PrevAmt_May', 'PrevAmt_April', 'Default'],
#       dtype='object')

# %%
A = credit['Repay_Sept']
plt.boxplot(A,0, 'gD')
plt.show()

# %%
A = credit['Bill_Sept']
plt.boxplot(A, 0, 'gD')
plt.show()

# %%
# Correlation Matrix
corrMat = credit.corr()
print(corrMat)
# Out:
#                      ID  Credit Amount       Age  Repay_Sept  Repay_Aug  \
# ID             1.000000       0.026179  0.018678   -0.030575  -0.011215
# Credit Amount  0.026179       1.000000  0.144713   -0.271214  -0.296382
# Age            0.018678       0.144713  1.000000   -0.039447  -0.050148
# Repay_Sept    -0.030575      -0.271214 -0.039447    1.000000   0.672164
# Repay_Aug     -0.011215      -0.296382 -0.050148    0.672164   1.000000
# Repay_July    -0.018494      -0.286123 -0.053048    0.574245   0.766552
# Repay_June    -0.002735      -0.267460 -0.049722    0.538841   0.662067
# Repay_May     -0.022199      -0.249411 -0.053826    0.509426   0.622780
# Repay_April   -0.020270      -0.235195 -0.048773    0.474553   0.575501
# Bill_Sept      0.019389       0.285430  0.056239    0.187068   0.234887
# Bill_Aug       0.017982       0.278314  0.054283    0.189859   0.235257
# Bill_July      0.024354       0.283236  0.053710    0.179785   0.224146
# ...

# %%
# Covariance matrix
covMat = credit.cov()
print(covMat)
# Out:
#                          ID  Credit Amount            Age    Repay_Sept  \
# ID             7.500250e+07   2.941664e+07    1491.057019   -297.572636
# Credit Amount  2.941664e+07   1.683446e+10  173076.722569 -39545.930009
# Age            1.491057e+03   1.730767e+05      84.969755     -0.408639
# Repay_Sept    -2.975726e+02  -3.954593e+04      -0.408639      1.262930
# Repay_Aug     -1.162770e+02  -4.603765e+04      -0.553408      0.904330
# Repay_July    -1.916922e+02  -4.443225e+04      -0.585263      0.772384
# Repay_June    -2.769132e+01  -4.057181e+04      -0.535851      0.707972
# Repay_May     -2.178600e+02  -3.667056e+04      -0.562245      0.648743
# Repay_April   -2.018774e+02  -3.509308e+04      -0.517022      0.613292
# Bill_Sept      1.236447e+07   2.727020e+09   38172.933546  15480.304170
# Bill_Aug       1.108392e+07   2.570130e+09   35613.657962  15185.916919
# Bill_July      1.462688e+07   2.548533e+09   34334.251320  14011.556537
# ...

# %%
# EDA for credit data
# Finding breakout by gender
credit.groupby('Gender')['Gender'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0b9e1db55e61> in <module>()
#       1 # EDA for credit data
#       2 # Finding breakout by gender
# ----> 3 credit.groupby('Gender')['Gender'].count()
#
# NameError: name 'credit' is not defined

# %%
import pandas as pd
credit = pd.io.parsers.read_csv["credit.csv"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-0fb9e9ceb0e0> in <module>()
#       1 import pandas as pd
# ----> 2 credit = pd.io.parsers.read_csv["credit.csv"]
#
# TypeError: 'function' object is not subscriptable

# %%
import csv
with open('credit.csv') as csvfile
readCSV = csv.reader(credit, delimiter= ',')
for row in readCSV:
    print(row)
    print(row[0])
# Out:
#   File "<ipython-input-2-98658e9d27fc>", line 2
#     with open('credit.csv') as csvfile
#                                       ^
# SyntaxError: invalid syntax

# %%
# need to reimport libraries and dataset
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# set default matplot figure size
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c9b52686b1c4> in <module>()
#       9
#      10 # set default matplot figure size
# ---> 11 pylab.rcParams['figure.figsize'] = (10.0, 8.0)
#
# NameError: name 'pylab' is not defined

# %%
credit = pd.read_csv('credit.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-7509b09058b6> in <module>()
# ----> 1 credit = pd.read_csv('credit.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
credit2 = pd.read_csv('default of credit card clients.csv')

# %%
credit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30001 entries, 0 to 30000
# Data columns (total 25 columns):
# Unnamed: 0    30001 non-null object
# X1            30001 non-null object
# X2            30001 non-null object
# X3            30001 non-null object
# X4            30001 non-null object
# X5            30001 non-null object
# X6            30001 non-null object
# X7            30001 non-null object
# X8            30001 non-null object
# X9            30001 non-null object
# X10           30001 non-null object
# X11           30001 non-null object
# X12           30001 non-null object
# X13           30001 non-null object
# X14           30001 non-null object
# X15           30001 non-null object
# X16           30001 non-null object
# X17           30001 non-null object
# X18           30001 non-null object
# X19           30001 non-null object
# X20           30001 non-null object
# X21           30001 non-null object
# X22           30001 non-null object
# ...

# %%
# upload data set and rename credit
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                30000 non-null int64
# Credit Amount     30000 non-null int64
# Gender            30000 non-null int64
# Education         30000 non-null int64
# Marital Status    30000 non-null int64
# Age               30000 non-null int64
# Repay_Sept        30000 non-null int64
# Repay_Aug         30000 non-null int64
# Repay_July        30000 non-null int64
# Repay_June        30000 non-null int64
# Repay_May         30000 non-null int64
# Repay_April       30000 non-null int64
# Bill_Sept         30000 non-null int64
# Bill_Aug          30000 non-null int64
# Bill_July         30000 non-null int64
# Bill_June         30000 non-null int64
# Bill_May          30000 non-null int64
# Bill_April        30000 non-null int64
# PrevAmt_Sept      30000 non-null int64
# PrevAmt_Aug       30000 non-null int64
# PrevAmt_July      30000 non-null int64
# ...

# %%
# changing data types for gender, education, marital status and default
credit['Gender'] = credit['Gender'].astype('str')
credit['Education'] = credit['Education'].astype('str')
credit['Marital Status'] = credit['Marital Status'].astype('str')
credit['Default'] = credit['Default'].astype('str')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                30000 non-null int64
# Credit Amount     30000 non-null int64
# Gender            30000 non-null object
# Education         30000 non-null object
# Marital Status    30000 non-null object
# Age               30000 non-null int64
# Repay_Sept        30000 non-null int64
# Repay_Aug         30000 non-null int64
# Repay_July        30000 non-null int64
# Repay_June        30000 non-null int64
# Repay_May         30000 non-null int64
# Repay_April       30000 non-null int64
# Bill_Sept         30000 non-null int64
# Bill_Aug          30000 non-null int64
# Bill_July         30000 non-null int64
# Bill_June         30000 non-null int64
# Bill_May          30000 non-null int64
# Bill_April        30000 non-null int64
# PrevAmt_Sept      30000 non-null int64
# PrevAmt_Aug       30000 non-null int64
# PrevAmt_July      30000 non-null int64
# ...

# %%
# looking at groups - education
credit.groupby('Education')['Education'].count()
# Out:
# Education
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: Education, dtype: int64

# %%
# looking at groups - marital status
credit.groupby('Marital Status')['Marital Status'].count()
# Out:
# Marital Status
# 0       54
# 1    13659
# 2    15964
# 3      323
# Name: Marital Status, dtype: int64

# %%
# looking at groups - marital status
credit.groupby('Default')['Default'].count()
# Out:
# Default
# 0    23364
# 1     6636
# Name: Default, dtype: int64

# %%
# bar graph of attributes
sns.factorplot('Gender', data =credit, kind = 'count', aspect = 1.5)

# %%
# bar graph of attributes
sns.factorplot('Education', data =credit, kind = 'count', aspect = 1.5)

# %%
# bar graph of attributes
sns.factorplot('Marital Status', data =credit, kind = 'count', aspect = 1.5)

# %%
# bar graph of attributes
sns.factorplot('Default', data =credit, kind = 'count', aspect = 1.5)

# %%
# looking at groups - marital status
credit.groupby('Gender')['Gender'].count()
# Out:
# Gender
# 1    11888
# 2    18112
# Name: Gender, dtype: int64

# %%
# group by gender and default
g = sns.factorplot('Gender', data = credit, hue = 'Default', kind = 'count', aspect = 1.75)
g.set_xlables('Default')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1c212f5ecb16> in <module>()
#       1 # group by gender and default
#       2 g = sns.factorplot('Gender', data = credit, hue = 'Default', kind = 'count', aspect = 1.75)
# ----> 3 g.set_xlables('Default')
#
# AttributeError: 'FacetGrid' object has no attribute 'set_xlables'

# %%
# graphing education levels by default 
g = sns.factorplot('Default', data = credit, hue = 'Education', kind = 'count', aspect = 1.75)

# %%
# graphing education levels by default 
g = sns.factorplot('Education', data = credit, hue = 'Default', kind = 'count', aspect = 1.75)

# %%
# saving csv file with changes to data types
credit.to_csv("credit.csv", index=False)

# %%
# looking at age distribution
age_dist = sns.distplot(credit['Age'])

# %%
# grouping ages in bins
credit['Age'].hist(bins=10)

# %%
# looking at different numbers of bins
credit['Age'].hist(bins=20)

# %%
fig = sns.FacetGrid(credit, hue = 'Gender', aspect = 4)
fig.map(sns.kdeplot, 'Age', shade = True)
oldest = credit['Age'].max()
fig.set(xlim=(0,oldest))
fig.set(title = 'Distribution of Age grouped by Gender')
fig.set_legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-9f2ddfc2dbef> in <module>()
#       4 fig.set(xlim=(0,oldest))
#       5 fig.set(title = 'Distribution of Age grouped by Gender')
# ----> 6 fig.set_legend()
#
# AttributeError: 'FacetGrid' object has no attribute 'set_legend'

# %%
# running again with min age = 19 and adding legend
fig = sns.FacetGrid(credit, hue = 'Gender', aspect = 4)
fig.map(sns.kdeplot, 'Age', shade = True)
oldest = credit['Age'].max()
fig.set(xlim=(19,oldest))
fig.set(title = 'Distribution of Age grouped by Gender')
fig.add_legend()

# %%
# running again with age and default 
fig = sns.FacetGrid(credit, hue = 'Default', aspect = 4)
fig.map(sns.kdeplot, 'Default', shade = True)
oldest = credit['Age'].max()
fig.set(xlim=(19,oldest))
fig.set(title = 'Distribution of Default grouped by Age')
fig.add_legend()
# Out:
# C:\Users\joann\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:494: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X,a,b,gridsize)/(delta*nobs)
# C:\Users\joann\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\joann\Anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)

# %%
# rerunning code that worked to try to understand error in line 34
fig = sns.FacetGrid(credit, hue = 'Gender', aspect = 4)
fig.map(sns.kdeplot, 'Age', shade = True)
oldest = credit['Age'].max()
fig.set(xlim=(19,oldest))
fig.set(title = 'Distribution of Age grouped by Gender')
fig.add_legend()

# %%
# trying another version - age against marital status
fig = sns.FacetGrid(credit, hue = 'Marital Status', aspect = 4)
fig.map(sns.kdeplot, 'Age', shade = True)
oldest = credit['Age'].max()
fig.set(xlim=(19,oldest))
fig.set(title = 'Distribution of Age grouped by Marital Status')
fig.add_legend()

# %%
# Running default against age.Original error with Default used in second line (fig.map) - should be age
fig = sns.FacetGrid(credit, hue = 'Default', aspect = 4)
fig.map(sns.kdeplot, 'Age', shade = True)
oldest = credit['Age'].max()
fig.set(xlim=(19,oldest))
fig.set(title = 'Distribution of Age grouped by Default')
fig.add_legend()

# %%
# Running default against default rate against credit amount
fig = sns.FacetGrid(credit, hue = 'Default', aspect = 4)
fig.map(sns.kdeplot, 'Credit Amount', shade = True)
oldest = credit['Credit Amount'].max()
fig.set(xlim=(0,oldest))
fig.set(title = 'Distribution of Credit Amount grouped by Default')
fig.add_legend()

# %%
# looking at distributions for other attributes
age_dist = sns.distplot(credit['Credit Amount'])

# %%
credit['Credit Amount'].hist(bins=6)

# %%
repay_sept = sns.distplot(credit['Repay_Sept'])

# %%
# graphing Sept repayments
sns.factorplot('Repay_Sept', data=credit, kind='count', aspect = 1.75, palette='winter_d')

# %%
# graphing Aug repayments and guessing at color palettes
sns.factorplot('Repay_Aug', data=credit, kind='count', aspect = 1.75, palette='spring_d')

# %%
# graphing Aug repayments and guessing at color palettes
sns.factorplot('Repay_July', data=credit, kind='count', aspect = 1.75, palette='summer_d')

# %%
# graphing Aug repayments and guessing at color palettes
sns.factorplot('Repay_June', data=credit, kind='count', aspect = 1.75, palette='Vega10')
# Out:
# C:\Users\joann\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: The Vega10 colormap was deprecated in version 2.0. Use tab10 instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# graphing Aug repayments and guessing at color palettes
sns.factorplot('Repay_May', data=credit, kind='count', aspect = 1.75, palette='gist_rainbow')

# %%
# need to reimport libraries and dataset
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %pylab inline

# set default matplot figure size
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# importing cleanded up data set (Education now has all 'others' grouped together)
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                30000 non-null int64
# Credit Amount     30000 non-null int64
# Gender            30000 non-null int64
# Education         30000 non-null int64
# Marital Status    30000 non-null int64
# Age               30000 non-null int64
# Repay_Sept        30000 non-null int64
# Repay_Aug         30000 non-null int64
# Repay_July        30000 non-null int64
# Repay_June        30000 non-null int64
# Repay_May         30000 non-null int64
# Repay_April       30000 non-null int64
# Bill_Sept         30000 non-null int64
# Bill_Aug          30000 non-null int64
# Bill_July         30000 non-null int64
# Bill_June         30000 non-null int64
# Bill_May          30000 non-null int64
# Bill_April        30000 non-null int64
# PrevAmt_Sept      30000 non-null int64
# PrevAmt_Aug       30000 non-null int64
# PrevAmt_July      30000 non-null int64
# ...

# %%
# changing data types for gender, education, marital status and default with new dataset
credit['Gender'] = credit['Gender'].astype('str')
credit['Education'] = credit['Education'].astype('str')
credit['Marital Status'] = credit['Marital Status'].astype('str')
credit['Default'] = credit['Default'].astype('str')

# %%
# looking at education for new data set
credit.groupby('Education')['Education'].count()
# Out:
# Education
# 1    10585
# 2    14030
# 3     4917
# 4      468
# Name: Education, dtype: int64

# %%
# trying to create stacked bar with credit amount and default
sns.set(style = "ticks")
sns.pairplot(credit["Credit Amount"], hue="Default")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-6139caa6d872> in <module>()
#       1 sns.set(style = "ticks")
# ----> 2 sns.pairplot(credit["Credit Amount"], hue="Default")
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2025         raise TypeError(
#    2026             "'data' must be pandas DataFrame object, not: {typefound}".format(
# -> 2027                 typefound=type(data)))
#    2028
#    2029     if plot_kws is None:
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'pandas.core.series.Series'>

# %%
sns.pairplot(credit, hue ="Default")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-07004407b6c8> in <module>()
# ----> 1 sns.pairplot(credit, hue ="Default")
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2058     if grid.square_grid:
#    2059         if diag_kind == "hist":
# -> 2060             grid.map_diag(plt.hist, **diag_kws)
#    2061         elif diag_kind == "kde":
#    2062             diag_kws["legend"] = False
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_diag(self, func, **kwargs)
#    1363                     func(vals, color=color, **kwargs)
#    1364                 else:
# -> 1365                     func(vals, color=color, histtype="barstacked", **kwargs)
#    1366
#    1367             else:
#
# ...

# %%
print(sns.pairplot)

# %%
# trying other graph types - violin plot
sns.set_style('whitegrid')
sns.violinplot(x='Education', y='Default', data = credit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in fit_kde(self, x, bw)
#     711         try:
# --> 712             kde = stats.gaussian_kde(x, bw)
#     713         except TypeError:
#
# ~\Anaconda3\lib\site-packages\scipy\stats\kde.py in __init__(self, dataset, bw_method)
#     171         self.d, self.n = self.dataset.shape
# --> 172         self.set_bandwidth(bw_method=bw_method)
#     173
#
# ~\Anaconda3\lib\site-packages\scipy\stats\kde.py in set_bandwidth(self, bw_method)
#     498
# --> 499         self._compute_covariance()
#     500
#
# ~\Anaconda3\lib\site-packages\scipy\stats\kde.py in _compute_covariance(self)
#     508             self._data_covariance = atleast_2d(np.cov(self.dataset, rowvar=1,
# --> 509                                                bias=False))
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                30000 non-null int64
# Credit Amount     30000 non-null int64
# Gender            30000 non-null object
# Education         30000 non-null object
# Marital Status    30000 non-null object
# Age               30000 non-null int64
# Repay_Sept        30000 non-null int64
# Repay_Aug         30000 non-null int64
# Repay_July        30000 non-null int64
# Repay_June        30000 non-null int64
# Repay_May         30000 non-null int64
# Repay_April       30000 non-null int64
# Bill_Sept         30000 non-null int64
# Bill_Aug          30000 non-null int64
# Bill_July         30000 non-null int64
# Bill_June         30000 non-null int64
# Bill_May          30000 non-null int64
# Bill_April        30000 non-null int64
# PrevAmt_Sept      30000 non-null int64
# PrevAmt_Aug       30000 non-null int64
# PrevAmt_July      30000 non-null int64
# ...

# %%
# trying other graph types - violin plot 
# retrying with integer types
sns.set_style('whitegrid')
sns.violinplot(x='Bill_Sept', y='PrevAmt_Sept', data = credit)

# %%
# graphing Sept repayments
# rerunning old graphs to see why new graphs aren't showing
sns.factorplot('Repay_Sept', data=credit, kind='count', aspect = 1.75, palette='winter_d')

# %%
# Looking into why sns. plots not displaying. Removing % pylab inline lneed to reimport libraries and dataset
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %pylab inline

# set default matplot figure size
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Looking into why sns. plots not displaying. Removing % pylab inline lneed to reimport libraries and dataset
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# set default matplot figure size
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d46729f3391b> in <module>()
#       9
#      10 # set default matplot figure size
# ---> 11 pylab.rcParams['figure.figsize'] = (10.0, 8.0)
#
# NameError: name 'pylab' is not defined

# %%
# importing cleanded up data set (Education now has all 'others' grouped together)
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
# looking at education for new data set
credit.groupby('Education')['Education'].count()
# Out:
# Education
# 1    10585
# 2    14030
# 3     4917
# 4      468
# Name: Education, dtype: int64

# %%
# retrying violin plot before changing data types to obj
# trying other graph types - violin plot
sns.set_style('whitegrid')
sns.violinplot(x='Education', y='Default', data = credit)

# %%
# graphing Sept repayments
sns.factorplot('Repay_Sept', data=credit, kind='count', aspect = 1.75, palette='rainbow')

# %%
# trying different graphs
sns.lmplot(x='Education', y='Credit Amount', data = credit)

# %%
#trying different graphs - (needed to interupt Kernel)
sns.swarmplot(x='Education', y= 'Credit Amount', data = credit, hue = 'Default')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-70a97003951d> in <module>()
# ----> 1 sns.swarmplot(x='Education', y= 'Credit Amount', data = credit, hue = 'Default')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2798                        linewidth=linewidth))
#    2799
# -> 2800     plotter.plot(ax, kwargs)
#    2801     return ax
#    2802
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1433     def plot(self, ax, kws):
#    1434         """Make the full plot."""
# -> 1435         self.draw_swarmplot(ax, kws)
#    1436         self.add_legend_data(ax)
#    1437         self.annotate_axes(ax)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_swarmplot(self, ax, kws)
# ...

# %%
# looking at other graphs - scatterplot
sns.stripplot(x='Education', y = 'Credit Amount', data = credit, jitter=True)

# %%
# looking at other graphs - scatterplot (trying to change size of graph)
sns.stripplot(x='Education', y = 'Credit Amount', data = credit, jitter=True,size = 10)

# %%
# looking at other graphs - scatterplot (trying to change size of graph with aspect ratio)
sns.stripplot(x='Education', y = 'Credit Amount', data = credit, jitter=True, aspect = 1.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-54b216f52751> in <module>()
#       1 # looking at other graphs - scatterplot (trying to change size of graph with aspect ratio)
# ----> 2 sns.stripplot(x='Education', y = 'Credit Amount', data = credit, jitter=True, aspect = 1.5)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2601                        linewidth=linewidth))
#    2602
# -> 2603     plotter.plot(ax, kwargs)
#    2604     return ax
#    2605
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1189     def plot(self, ax, kws):
#    1190         """Make the plot."""
# -> 1191         self.draw_stripplot(ax, kws)
#    1192         self.add_legend_data(ax)
# ...

# %%
sns.set(style="whitegrid")
sns.barplot(x="Education", y = "Gender", data = credit, label= "Education")

# %%
sns.set(style="whitegrid")
sns.barplot(x="Education", y = "Gender", data = credit, label= "Default")

# %%
sns.set(style="white", rc={"axes.facecolor": (0,0,0,0)})
pal = sns.cubehelix_palette(10, rot=-25, light=.7)
g = sns.FacetGrid(credit, row ="Education", hue="Education", aspect = 15, size = .5, palette = pal)
g.map(sns.kdeplot, "x", clip_on=False, shade = True, alpha=1, lw=1.5, bw=.2)
g.map(sns.kdeplot, "x", clip_on=False, color="w", lw=2, bw=.2)
g.map(plt.axhline, y=0, lw=2, clip_on=False)
g.fig.subplots_adjust(hspace=-.25)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-39bdeee48a3e> in <module>()
#       2 pal = sns.cubehelix_palette(10, rot=-25, light=.7)
#       3 g = sns.FacetGrid(credit, row ="Education", hue="Education", aspect = 15, size = .5, palette = pal)
# ----> 4 g.map(sns.kdeplot, "x", clip_on=False, shade = True, alpha=1, lw=1.5, bw=.2)
#       5 g.map(sns.kdeplot, "x", clip_on=False, color="w", lw=2, bw=.2)
#       6 g.map(plt.axhline, y=0, lw=2, clip_on=False)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     730
#     731             # Get the actual data we are going to plot with
# --> 732             plot_data = data_ijk[list(args)]
#     733             if self._dropna:
#     734                 plot_data = plot_data.dropna()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
# ...

# %%
fig, axes = joypy.joyplot(credit, by="Education")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f53ae4638221> in <module>()
# ----> 1 fig, axes = joypy.joyplot(credit, by="Education")
#
# NameError: name 'joypy' is not defined

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                30000 non-null int64
# Credit Amount     30000 non-null int64
# Gender            30000 non-null int64
# Education         30000 non-null int64
# Marital Status    30000 non-null int64
# Age               30000 non-null int64
# Repay_Sept        30000 non-null int64
# Repay_Aug         30000 non-null int64
# Repay_July        30000 non-null int64
# Repay_June        30000 non-null int64
# Repay_May         30000 non-null int64
# Repay_April       30000 non-null int64
# Bill_Sept         30000 non-null int64
# Bill_Aug          30000 non-null int64
# Bill_July         30000 non-null int64
# Bill_June         30000 non-null int64
# Bill_May          30000 non-null int64
# Bill_April        30000 non-null int64
# PrevAmt_Sept      30000 non-null int64
# PrevAmt_Aug       30000 non-null int64
# PrevAmt_July      30000 non-null int64
# ...

# %%
# trying grouped box plots (looking at credit amount by education level and gender)
sns.set(style = "ticks")

sns.boxplot(x="Education", y="Credit Amount", hue ="Gender", data=credit, palette="PRGn")
sns.despine(offset=10, trim=True)

# %%
# trying grouped box plots (looking at credit amount by education level and Default)
sns.set(style = "ticks")

sns.boxplot(x="Education", y="Credit Amount", hue ="Default", data=credit, palette="PRGn")
sns.despine(offset=10, trim=True)

# %%
# trying grouped box plots (looking at credit amount by Marital status and Default)
sns.set(style = "ticks")

sns.boxplot(x="Marital Status", y="Credit Amount", hue ="Default", data=credit, palette="PRGn")
sns.despine(offset=10, trim=True)

# %%
# looking at other graphs - swarmplot
sns.swarmplot(x='Education', y = 'Credit Amount', hue ="Default", data = credit);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-d22ce5bab1ab> in <module>()
#       1 # looking at other graphs - swarmplot
# ----> 2 sns.swarmplot(x='Education', y = 'Credit Amount', hue ="Default", data = credit);
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2798                        linewidth=linewidth))
#    2799
# -> 2800     plotter.plot(ax, kwargs)
#    2801     return ax
#    2802
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1433     def plot(self, ax, kws):
#    1434         """Make the full plot."""
# -> 1435         self.draw_swarmplot(ax, kws)
#    1436         self.add_legend_data(ax)
#    1437         self.annotate_axes(ax)
#
# ...

# %%
g = sns.PairGrid(credit, x_vars = ["Education", "Gender", "Marital Status"],
                y_vars = ["Default"],
                aspect=.75, size=3.5)
g.map(sns.factorplot, palette = "PRGn");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-ac953132e471> in <module>()
#       2                 y_vars = ["Default"],
#       3                 aspect=.75, size=3.5)
# ----> 4 g.map(sns.factorplot, palette = "PRGn");
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
#    1302                     color = self.palette[k] if kw_color is None else kw_color
#    1303                     func(data_k[x_var], data_k[y_var],
# -> 1304                          label=label_k, color=color, **kwargs)
#    1305
#    1306                 self._clean_axis(ax)
#
# ...

# %%
g = sns.PairGrid(credit, x_vars = ["Education", "Gender", "Marital Status"],
                y_vars = ["Default"],
                aspect=.75, size=3.5)
g.map(sns.violinplot, palette = "PRGn");

# %%
# changing data types for gender, education, marital status and default
credit['Gender'] = credit['Gender'].astype('str')
credit['Eduction'] = credit['Education'].astype('str')
credit['Marital Status'] = credit['Marital Status'].astype('str')
credit['Default'] = credit['Default'].astype('str')

# %%
sns.factorplot('Education', data = credit, kind='count', hue='Default', order=[1,2,3,4], hue_order=["0","1"], 
               aspect=1.25, size=5)

# %%
# linear plot of age vs. default
sns.lmplot('Age', 'Default', data=credit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-deb57c6a9667> in <module>()
#       1 # linear plot of age vs. default
# ----> 2 sns.lmplot('Age', 'Default', data=credit)
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     588         scatter_kws=scatter_kws, line_kws=line_kws,
#     589         )
# --> 590     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     591
#     592     # Add a legend
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     807
# ...

# %%
# linear plot of age vs. credit amount (both type = int)
sns.lmplot('Age', 'Credit Amount', data=credit, hue = 'Default')

# %%
# looking at amount of bill each month to repayment status. 1st step - looking at number of bins
credit.groupby('Repay_Sept')['Repay_Sept'].count()
# Out:
# Repay_Sept
# -2     2759
# -1     5686
#  0    14737
#  1     3688
#  2     2667
#  3      322
#  4       76
#  5       26
#  6       11
#  7        9
#  8       19
# Name: Repay_Sept, dtype: int64

# %%
# looking at distribution of repayment amount by repayment status for Sept
fig=sns.FacetGrid(credit, hue = 'Repay_Sept', aspect = 5)
fig.map(sns.kdeplot, 'Bill_Sept', shade=True)
highest=credit['Bill_Sept'].max()
fig.set(xlim=(0,highest))
fig.set(title='Repayment Amount for Sept')
fig.add_legend()

# %%
# linear plot of bill amount vs amount paid - Sept
sns.lmplot('Bill_Sept', 'PrevAmt_Sept', data=credit, hue = 'Default')

# %%
# Working on heat map of Gender and Education for Defaulted and non defaulted clients
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    
with sns.axes_style("dark"):
    g= sns.FacetGrid(credit, hue = "Default", col="Default", size=4)
g.map(hexbin, "Education", "Gender", extent=[0, 4, 0, 2])

# %%
# upload data set with the repay status column averages and name avgrepay
avgrepay = pd.read_csv('credit default with average.csv', header =1)

# %%
# view data
avgrepay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 26 columns):
# ID                30000 non-null int64
# Credit Amount     30000 non-null int64
# Gender            30000 non-null int64
# Education         30000 non-null int64
# Marital Status    30000 non-null int64
# Age               30000 non-null int64
# Repay_Sept        30000 non-null int64
# Repay_Aug         30000 non-null int64
# Repay_July        30000 non-null int64
# Repay_June        30000 non-null int64
# Repay_May         30000 non-null int64
# Repay_April       30000 non-null int64
# Repay_Avg         30000 non-null float64
# Bill_Sept         30000 non-null int64
# Bill_Aug          30000 non-null int64
# Bill_July         30000 non-null int64
# Bill_June         30000 non-null int64
# Bill_May          30000 non-null int64
# Bill_April        30000 non-null int64
# PrevAmt_Sept      30000 non-null int64
# PrevAmt_Aug       30000 non-null int64
# ...

# %%
avgpay=sns.distplot(avgrepay['Repay_Avg'])

# %%
# trying grouped box plots (looking at credit amount by education level and gender)
sns.set(style = "ticks")

sns.boxplot(x="Repay_Sept", y="PrevAmt_Sept", hue ="Default", data=credit, palette="PRGn")
sns.despine(offset=5, trim=True)

# %%
# linear plot of bill amount vs amount paid - Sept
sns.lmplot('Repay_Sept', 'Bill_Sept', data=credit, hue = 'Default')

# %%
# running example for Nick
sns.factorplot('Education', data=credit, kind = 'count', hue = 'Gender', order=[1,2,3,4],
               hue_order=["1", "2"], aspect=2)

# %%
# Reloading module after closing out of system
# Looking into why sns. plots not displaying. Removing % pylab inline lneed to reimport libraries and dataset
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# set default matplot figure size
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d46729f3391b> in <module>()
#       9
#      10 # set default matplot figure size
# ---> 11 pylab.rcParams['figure.figsize'] = (10.0, 8.0)
#
# NameError: name 'pylab' is not defined

# %%
# importing cleanded up data set (Education now has all 'others' grouped together)
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
# changing data types for gender, education, marital status and default
credit['Gender'] = credit['Gender'].astype('str')
credit['Eduction'] = credit['Education'].astype('str')
credit['Marital Status'] = credit['Marital Status'].astype('str')
credit['Default'] = credit['Default'].astype('str')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 26 columns):
# ID                30000 non-null int64
# Credit Amount     30000 non-null int64
# Gender            30000 non-null object
# Education         30000 non-null int64
# Marital Status    30000 non-null object
# Age               30000 non-null int64
# Repay_Sept        30000 non-null int64
# Repay_Aug         30000 non-null int64
# Repay_July        30000 non-null int64
# Repay_June        30000 non-null int64
# Repay_May         30000 non-null int64
# Repay_April       30000 non-null int64
# Bill_Sept         30000 non-null int64
# Bill_Aug          30000 non-null int64
# Bill_July         30000 non-null int64
# Bill_June         30000 non-null int64
# Bill_May          30000 non-null int64
# Bill_April        30000 non-null int64
# PrevAmt_Sept      30000 non-null int64
# PrevAmt_Aug       30000 non-null int64
# PrevAmt_July      30000 non-null int64
# ...

# %%
# Working on heat map of Gender and Education for Defaulted and non defaulted clients (comments from Mike on plt.hexib line)
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x,y, gridsize=10, cmap=cmap, **kwargs)
    
with sns.axes_style("dark"):
    g= sns.FacetGrid(credit, hue = "Default", col="Default", size=2)
g.map(hexbin, "Education", "Gender", extent=[0, 4, 0, 2])

# %%
# looking at relationship between repayment status and default
g = sns.factorplot("Repay_Sept", col="Default", col_wrap=4,
                  data = credit, kind = 'count', size =10, aspect = 3)

# %%
g = sns.factorplot("Repay_Aug", col="Default", col_wrap=4,
                  data = credit, kind = 'count', size =10, aspect = 3)

# %%
# Comparing repayment status to number of defaults for each month
g = sns.factorplot("Default", col="Repay_Sept", col_wrap=4,
                  data = credit, kind = 'count', size =2.5, aspect =.8)

# %%
g = sns.factorplot("Default", col="Repay_Aug", col_wrap=4,
                  data = credit, kind = 'count', size =2.5, aspect =.8)

# %%
g = sns.factorplot("Default", col="Repay_July", col_wrap=4,
                  data = credit, kind = 'count', size =2.5, aspect =.8)

# %%
g = sns.factorplot("Default", col="Repay_June", col_wrap=4,
                  data = credit, kind = 'count', size =2.5, aspect =.8)

# %%
g = sns.factorplot("Default", col="Repay_May", col_wrap=4,
                  data = credit, kind = 'count', size =2.5, aspect =.8)

# %%
g = sns.factorplot("Default", col="Repay_April", col_wrap=4,
                  data = credit, kind = 'count', size =2.5, aspect =.8)

# %%
g=sns.PairGrid(credit, vars=["Bill_Sept", "PrevAmt_Sept"])
g = g.map(plt.scatter)

# %%
sns.lmplot('Age', 'Default', data=credit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-ce9c8cf70b31> in <module>()
# ----> 1 sns.lmplot('Age', 'Default', data=credit)
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     588         scatter_kws=scatter_kws, line_kws=line_kws,
#     589         )
# --> 590     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     591
#     592     # Add a legend
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     807
#     808             # Draw the plot
# ...

# %%
# changing default back to integer
credit['Default'] = credit['Default'].astype('int')

# %%
sns.lmplot('Age', 'Default', data=credit)

# %%
sns.lmplot('Education', 'Default', data=credit)

# %%
sns.lmplot('Credit Amount', 'Default', data=credit)

# %%
sns.lmplot('Age', 'Default', hue = 'Gender', data = credit)

# %%
g = sns.factorplot("Default", col="Marital Status", col_wrap=4,
                  data = credit, kind = 'count', size =2.5, aspect =.8)
